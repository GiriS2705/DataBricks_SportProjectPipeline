# %%
# Catalog
catalog_name = "workauto"

# Schemas
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema = "gold"

# S3 Paths
csv_path = "s3://your-bucket/raw/csv/"
json_path = "s3://your-bucket/raw/json/"
txt_path = "s3://your-bucket/raw/txt/"
